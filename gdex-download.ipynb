.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2009090106_2009091606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2009091606_2009100106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2009100106_2009101606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2009101606_2009110106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2009110106_2009111606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2009111606_2009120106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2009120106_2009121606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2009121606_2010010106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010010106_2010011606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010011606_2010020106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010020106_2010021606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010021606_2010030106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010030106_2010031606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010031606_2010040106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010040106_2010041606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010041606_2010050106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010050106_2010051606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010051606_2010060106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010060106_2010061606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010061606_2010070106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010070106_2010071606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010071606_2010080106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010080106_2010081606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010081606_2010090106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010090106_2010091606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010091606_2010100106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010100106_2010101606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010101606_2010110106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010110106_2010111606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010111606_2010120106.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010120106_2010121606.nc",
 "https://request.gdex.ucar.edu/dsrqst/BORGSTEDTE824200/824200.LSP.e5.oper.fc.sfc.accumu.128_142_lsp.ll025sc.2010121606_2011010106.nc",
 ]

# %% [markdown]
# Change the value of `save_dir` if you prefer your files saved somewhere other than the current directory.

# %%
save_dir = ''

# %% [markdown]
#  ## Now to download the files

# %%
for file in filelist:
    filename = (save_dir + file).strip()
    print('Downloading', file)
    req = requests.get(filename, allow_redirects=True)
    open(os.path.basename(filename), 'wb').write(req.content)
# Out:
# ...
# ...
# ...

# %% [markdown]
# ### Once you have downloaded the data, the next part can help you plot it.

# %% [markdown]
# In order to plot this data, you may need to install some libraries. The easiest way to do this is to use conda or pip, however any method of getting the following libraries will work.

# %%
import xarray # used for reading the data.
import matplotlib.pyplot as plt # used to plot the data.
import ipywidgets as widgets # For ease in selecting variables.
import cartopy.crs as ccrs # Used to georeference data.

# %%
filelist_arr = [save_dir + os.path.basename(file) for file in filelist]
selected_file = widgets.Dropdown(options=filelist_arr, description='data file')
display(selected_file)
# Out:
# Dropdown(description='data file', options=('824200.CP.e5.oper.fc.sfc.accumu.128_143_cp.ll025sc.2000121606_2001…

# %%
# Now to load in the data to xarray
ds = xarray.open_dataset(selected_file.value)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\tomy3\miniforge3\envs\xarray-climate\Lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File c:\Users\tomy3\miniforge3\envs\xarray-climate\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('c:\\Users\\tomy3\\ATMS-523-Module-2-1\\824200.CP.e5.oper.fc.sfc.accumu.128_143_cp.ll025sc.2000121606_2001010106.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '0573e64d-babf-4519-b5f8-32a163e446ae']
#
# ...

# %%
# Helper methods# Define function to get standard dimensions
def get_primary(dataset):
    primary_variables = {}
    coords = dataset.coords.keys()
    highest_dims = 0
    for cur_key,cur_var in dataset.variables.items():
        if cur_key not in coords:
            primary_variables[cur_key] = cur_var
    return primary_variables

# %%
var = widgets.Dropdown(
    options=get_primary(ds).keys(),
    description='Variable')
display(var)

# %%
proj = ccrs.Mercator()
plt.gcf().set_size_inches(20,10)
ax = plt.axes(projection=proj)
data_slice = ds[var.value].isel(time=0)
data_slice.plot.contourf(ax=ax, transform=ccrs.PlateCarree())
ax.set_global()
ax.coastlines()
